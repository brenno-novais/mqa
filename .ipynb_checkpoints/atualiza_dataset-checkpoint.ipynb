# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split

# %%
# PANDAS OPTIONS
pd.set_option('display.max_columns', None)

# %%
# IMPORTA DATASET
df = pd.read_csv('datasets/custom/dataset_1.csv')

# %%
df
# Out:
#                                 ID da música  Duração (em segundos)  \
# 0     t_feb4ef97-cd30-4c33-9032-ef1f1a58d655             201.986664
# 1     t_7a7e4a76-7914-4d21-8773-6a54a0812de5             230.639999
# 2     t_f0db29da-fe13-472b-bfdf-d5a0bd783502             247.626663
# 3     t_c823babf-7191-49b0-ba86-48439914cc62             250.514297
# 4     t_93f9d8eb-6110-47d6-a1e4-6b6b9819f1d1             274.160004
# ...                                      ...                    ...
# 1010  t_7067ad63-1ac7-4449-87be-cdec400112ce             166.800003
# 1011  t_5a48ea7d-3e94-41a3-aa43-22791103ae33             165.067764
# 1012  t_975a672f-67e2-4fb9-a007-dd197a26da22             278.093323
# 1013  t_0b0afb51-07bb-4fe0-a3b3-75c43d1884ae             105.038368
# 1014  t_4a020a5e-82b2-4122-acbe-b1dd12256afd             272.466675
#
#       Estimativa de popularidade nos EUA  Dançabilidade   Energia  \
# 0                              99.835139       0.765982  0.761067
# ...

# %%
# Transformando duração em minutos
df['Duração (em segundos)'] = df['Duração (em segundos)']/60

# %%
df.rename(columns = {'Duração (em segundos)':'Duração (em minutos)'}, inplace = True)

# %%
df
# Out:
#                                 ID da música  Duração (em minutos)  \
# 0     t_feb4ef97-cd30-4c33-9032-ef1f1a58d655              3.366444
# 1     t_7a7e4a76-7914-4d21-8773-6a54a0812de5              3.844000
# 2     t_f0db29da-fe13-472b-bfdf-d5a0bd783502              4.127111
# 3     t_c823babf-7191-49b0-ba86-48439914cc62              4.175238
# 4     t_93f9d8eb-6110-47d6-a1e4-6b6b9819f1d1              4.569333
# ...                                      ...                   ...
# 1010  t_7067ad63-1ac7-4449-87be-cdec400112ce              2.780000
# 1011  t_5a48ea7d-3e94-41a3-aa43-22791103ae33              2.751129
# 1012  t_975a672f-67e2-4fb9-a007-dd197a26da22              4.634889
# 1013  t_0b0afb51-07bb-4fe0-a3b3-75c43d1884ae              1.750639
# 1014  t_4a020a5e-82b2-4122-acbe-b1dd12256afd              4.541111
#
#       Estimativa de popularidade nos EUA  Dançabilidade   Energia  \
# 0                              99.835139       0.765982  0.761067
# ...

# %%
# Criando arquivo csv da versão atualizada do dataset
df.to_csv('./datasets/custom/dataset_2.csv', index=False)
