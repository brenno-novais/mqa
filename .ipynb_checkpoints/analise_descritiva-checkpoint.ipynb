# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split
from scipy.stats import variation, normaltest

# %%
# PANDAS OPTIONS
pd.set_option('display.max_columns', None)

# %%
# IMPORTA DATASETE
df = pd.read_csv('datasets/custom/dataset_1.csv')

# %%
df
# Out:
#                                 ID da música  Duração (em segundos)  \
# 0     t_feb4ef97-cd30-4c33-9032-ef1f1a58d655             201.986664
# 1     t_7a7e4a76-7914-4d21-8773-6a54a0812de5             230.639999
# 2     t_f0db29da-fe13-472b-bfdf-d5a0bd783502             247.626663
# 3     t_c823babf-7191-49b0-ba86-48439914cc62             250.514297
# 4     t_93f9d8eb-6110-47d6-a1e4-6b6b9819f1d1             274.160004
# ...                                      ...                    ...
# 1010  t_7067ad63-1ac7-4449-87be-cdec400112ce             166.800003
# 1011  t_5a48ea7d-3e94-41a3-aa43-22791103ae33             165.067764
# 1012  t_975a672f-67e2-4fb9-a007-dd197a26da22             278.093323
# 1013  t_0b0afb51-07bb-4fe0-a3b3-75c43d1884ae             105.038368
# 1014  t_4a020a5e-82b2-4122-acbe-b1dd12256afd             272.466675
#
#       Estimativa de popularidade nos EUA  Dançabilidade   Energia  \
# 0                              99.835139       0.765982  0.761067
# 1                              99.982884       0.628740  0.736263
# 2                              99.973848       0.630953  0.749407
# 3                              99.447559       0.713650  0.619660
# 4                              99.791719       0.656329  0.654815
# ...                                  ...            ...       ...
# 1010                           99.923580       0.698223  0.724418
# 1011                           99.983575       0.725614  0.387775
# 1012                           99.939557       0.320929  0.887347
# 1013                           98.460405       0.795702  0.631768
# 1014                           99.892540       0.523690  0.518484
#
#       Instrumentalidade  Ano de Lançamento Escala musical  \
# 0          2.401338e-12               2017          Menor
# 1          4.961319e-08               2016          Maior
# 2          5.208510e-06               1971          Maior
# 3          6.433872e-01               2015          Menor
# 4          2.488995e-08               2016          Menor
# ...                 ...                ...            ...
# 1010       5.838772e-06               2010          Maior
# 1011       1.909367e-10               2015          Maior
# 1012       2.335636e-07               2015          Maior
# 1013       3.346265e-07               2018          Menor
# 1014       4.531301e-09               1996          Maior
#
#      Música foi pulada no início Música não foi pulada  \
# 0                          Falso                 Falso
# 1                     Verdadeiro            Verdadeiro
# 2                          Falso            Verdadeiro
# 3                          Falso            Verdadeiro
# 4                     Verdadeiro                 Falso
# ...                          ...                   ...
# 1010                  Verdadeiro                 Falso
# 1011                       Falso            Verdadeiro
# 1012                       Falso                 Falso
# 1013                  Verdadeiro            Verdadeiro
# 1014                       Falso            Verdadeiro
#
#       Escutada em qual hora do dia
# 0                                9
# 1                               14
# 2                               22
# 3                               16
# 4                               14
# ...                            ...
# 1010                            15
# 1011                            14
# 1012                             9
# 1013                            19
# 1014                            16
#
# [1015 rows x 11 columns]

# %%
# Criando máscaras
variaveis_quantitativas = {
    'Duração (em segundos)',
    'Estimativa de popularidade nos EUA',
    'Dançabilidade',
    'Energia',
    'Instrumentalidade',
}

variaveis_qualitativas = {
    'Ano de Lançamento',
    'Escala musical', 
    'Música foi pulada no início',
    'Música não foi pulada',
    'Escutada em qual hora do dia'
}

# %% [markdown]
# # Medidas Resumo

# %% [markdown]
# ## Média

# %%
df[variaveis_quantitativas].mean()
# Out:
# C:\Users\brenn\AppData\Local\Temp\ipykernel_20824\3031292147.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[variaveis_quantitativas].mean()
# Estimativa de popularidade nos EUA     99.467082
# Energia                                 0.649316
# Instrumentalidade                       0.067963
# Dançabilidade                           0.604742
# Duração (em segundos)                 225.772200
# dtype: float64

# %% [markdown]
# ## Moda

# %%
df[variaveis_quantitativas].value_counts().head(1)
# Out:
# C:\Users\brenn\AppData\Local\Temp\ipykernel_20824\2338202063.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[variaveis_quantitativas].value_counts().head(1)
# Estimativa de popularidade nos EUA  Energia   Instrumentalidade  Dançabilidade  Duração (em segundos)
# 90.249354                           0.892669  0.015934           0.598236       189.09288                1
# dtype: int64

# %% [markdown]
# ## Mediana

# %%
df[variaveis_quantitativas].median()
# Out:
# C:\Users\brenn\AppData\Local\Temp\ipykernel_20824\1847510118.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[variaveis_quantitativas].median()
# Estimativa de popularidade nos EUA     99.866510
# Energia                                 0.656656
# Instrumentalidade                       0.000002
# Dançabilidade                           0.617222
# Duração (em segundos)                 215.453323
# dtype: float64

# %% [markdown]
# # Histogramas

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# C:\Users\brenn\AppData\Local\Temp\ipykernel_20824\4283695574.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax = ax)
# array([[<AxesSubplot:title={'center':'Duração (em segundos)'}>,
#         <AxesSubplot:title={'center':'Estimativa de popularidade nos EUA'}>,
#         <AxesSubplot:title={'center':'Dançabilidade'}>],
#        [<AxesSubplot:title={'center':'Energia'}>,
#         <AxesSubplot:title={'center':'Instrumentalidade'}>,
#         <AxesSubplot:title={'center':'Ano de Lançamento'}>],
#        [<AxesSubplot:title={'center':'Escutada em qual hora do dia'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df['Música foi pulada no início'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Música não foi pulada'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Escala musical'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Medidas de Variabilidade

# %% [markdown]
# # Variância

# %%
df[variaveis_quantitativas].var()
# Out:
# C:\Users\brenn\AppData\Local\Temp\ipykernel_20824\3356078563.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[variaveis_quantitativas].var()
# Estimativa de popularidade nos EUA       1.206217
# Energia                                  0.040676
# Instrumentalidade                        0.044541
# Dançabilidade                            0.027743
# Duração (em segundos)                 5751.583457
# dtype: float64

# %% [markdown]
# ## Desvio Padrão

# %%
df[variaveis_quantitativas].std()
# Out:
# C:\Users\brenn\AppData\Local\Temp\ipykernel_20824\2757709137.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[variaveis_quantitativas].std()
# Estimativa de popularidade nos EUA     1.098279
# Energia                                0.201684
# Instrumentalidade                      0.211047
# Dançabilidade                          0.166564
# Duração (em segundos)                 75.839195
# dtype: float64

# %% [markdown]
# ## Coeficiente de Variação

# %%
coeficientes = variation(df[variaveis_quantitativas])
i = 0
for variavel in variaveis_quantitativas:
    print(variavel, coeficientes[i])
    i += 1
# Out:
# Estimativa de popularidade nos EUA 0.011036193711699642
# Energia 0.3104568378748597
# Instrumentalidade 3.103765555478325
# Dançabilidade 0.27529351701517296
# Duração (em segundos) 0.3357447298079407
# C:\Users\brenn\AppData\Local\Temp\ipykernel_20824\657214111.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   coeficientes = variation(df[variaveis_quantitativas])

# %% [markdown]
# # Avaliação de Normalidade

# %% [markdown]
# ## Distribuição Normal

# %%
for variavel in variaveis_quantitativas:
    plt.figure(figsize=(10,7), dpi= 80)
    sns.distplot(df[variavel], color="dodgerblue", label="Compact",)

    print(variavel)
    plt.show()

    alpha = 0.05
    k2, p = normaltest(df[variavel])

    #Hipotese nula: Os dados seguem distribuição normal
    #Hipotese alternativa: Os dados não seguem distribuição normal

    if p < alpha:
        print("A Hipótese Nula pode ser rejeitada")
    else:
        print("A hipótese nula não pode ser rejeitada")
    print('______________________________________________________________________________________________________________________\n\n')
# Out:
# Estimativa de popularidade nos EUA
# C:\Users\brenn\.virtualenvs\MQA-RNh3vqsr\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\brenn\.virtualenvs\MQA-RNh3vqsr\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# A Hipótese Nula pode ser rejeitada
# ______________________________________________________________________________________________________________________
#
#
# Energia
# C:\Users\brenn\.virtualenvs\MQA-RNh3vqsr\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# A Hipótese Nula pode ser rejeitada
# ______________________________________________________________________________________________________________________
#
#
# Instrumentalidade
# C:\Users\brenn\.virtualenvs\MQA-RNh3vqsr\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# A Hipótese Nula pode ser rejeitada
# ______________________________________________________________________________________________________________________
#
#
# Dançabilidade
# C:\Users\brenn\.virtualenvs\MQA-RNh3vqsr\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# A Hipótese Nula pode ser rejeitada
# ______________________________________________________________________________________________________________________
#
#
# Duração (em segundos)
# A Hipótese Nula pode ser rejeitada
# ______________________________________________________________________________________________________________________

# %% [markdown]
# # Separatrizes

# %%
df.quantile([.25, .5, .75], axis = 0)
# Out:
#       Duração (em segundos)  Estimativa de popularidade nos EUA  \
# 0.25             187.706146                           99.525457
# 0.50             215.453323                           99.866510
# 0.75             251.426170                           99.965101
#
#       Dançabilidade   Energia  Instrumentalidade  Ano de Lançamento  \
# 0.25       0.488060  0.521084       1.763880e-08             2008.0
# 0.50       0.617222  0.656656       1.742013e-06             2015.0
# 0.75       0.730999  0.809995       4.425801e-04             2017.0
#
#       Escutada em qual hora do dia
# 0.25                          11.0
# 0.50                          15.0
# 0.75                          18.0

# %%
for variavel in variaveis_quantitativas:
    fig = plt.figure(figsize =(10, 7)) 
    plt.boxplot(df[variavel]) 
    plt.show()
